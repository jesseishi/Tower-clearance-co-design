# %%
from weis.visualization.utils import load_OMsql_multi
import pandas as pd
import numpy as np

# %%
data = load_OMsql_multi(
    "/home/jesse/Projects/Tower-clearance-co-design/data/co-design/check_clearance/check_clearance.sql*"
)

# %%
df = pd.DataFrame(
    {
        "rank": data["rank"],
        "iter": data["iter"],
        "minimum_tower_clearance": data["aeroelastic.minimum_tower_clearance"],
        "minimum_eff_tower_clearance": data["aeroelastic.minimum_eff_tower_clearance"],
        "tilt": data["nacelle.uptilt"],
        "cone": data["hub.cone"],
        "maximum_tip_deflection": data["aeroelastic.max_eff_TipDxc_towerPassing"],
    }
)

# %%
df
