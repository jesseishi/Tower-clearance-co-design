# %% [markdown]
# ```
# rsync -avm --include='*/' --include='*.sql*' --include='*.outb' --include='*.RO.dbg' --exclude='*' jhummel@login.delftblue.tudelft.nl:../../scratch/jhummel/tip_clearance/data/optimal_tuning/check_AEP* ./data/optimal_tuning/ --dry-run
# ```
